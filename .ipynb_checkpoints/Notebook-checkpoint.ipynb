# %% [markdown]
# Project by : Ionas Andreea and Mihu Octavian

# %%
import pandas as pd
# Load test.csv
test_data = pd.read_csv('test.csv')

# Load train.csv
train_data = pd.read_csv('train.csv')

# %% [markdown]
# Data overview

# %%
print("Test Data Description:")
print(test_data.describe())
# Out:
# Test Data Description:
#           patient_id  patient_zip3  patient_age          bmi    population  \
# count    5646.000000   5646.000000  5646.000000  1705.000000   5646.000000
# mean   549581.847680    569.824655    58.921537    29.142798  20865.277040
# std    260549.557126    276.824893    13.326813     5.612167  14252.666477
# min    100401.000000    100.000000    18.000000    16.000000    829.520000
# 25%    325189.750000    330.000000    50.000000    24.840000   8893.480000
# 50%    551142.500000    554.000000    59.000000    28.340000  19154.190000
# 75%    773004.000000    836.000000    66.000000    33.140000  30145.890000
# max    999846.000000    997.000000    91.000000    43.700000  71374.130000
#
#             density   age_median  age_under_10  age_10_to_19      age_20s  \
# count   5646.000000  5646.000000   5646.000000   5646.000000  5646.000000
# mean    1826.421314    40.509499     11.123819     12.868130    13.291959
# std     3928.358993     3.983375      1.498752      1.906942     3.226722
# min        0.920000    30.030000      5.220000      6.310000     5.930000
# 25%      161.930000    37.130000     10.150000     11.680000    11.020000
# 50%      688.010000    40.640000     11.040000     12.920000    12.540000
# 75%     1686.320000    42.940000     12.190000     13.890000    14.970000
# max    29851.690000    54.570000     17.680000     24.900000    36.900000
#
#        ...  Average of Mar-18  Average of Apr-18  Average of May-18  \
# count  ...        5639.000000        5646.000000        5646.000000
# mean   ...          46.471807          52.753471          68.065220
# std    ...          12.057043          11.079245           6.304141
# min    ...          14.910000          25.670000          40.580000
# 25%    ...          36.440000          43.590000          63.260000
# 50%    ...          43.650000          51.200000          66.120000
# 75%    ...          58.990000          62.340000          72.690000
# max    ...          71.640000          76.490000          86.570000
#
#        Average of Jun-18  Average of Jul-18  Average of Aug-18  \
# count        5641.000000        5630.000000        5639.000000
# mean           73.188927          77.221172          76.388918
# std             6.539446           5.279963           5.239295
# min            49.620000          57.440000          50.300000
# 25%            68.160000          73.272500          72.550000
# 50%            71.750000          76.685000          76.330000
# 75%            77.920000          80.660000          79.580000
# max            90.660000          96.430000          95.770000
#
#        Average of Sep-18  Average of Oct-18  Average of Nov-18  \
# count        5644.000000        5644.000000        5638.000000
# mean           71.584807          59.669313          46.499769
# std             6.481236           9.311322          12.323264
# min            43.780000          32.020000          14.160000
# 25%            67.030000          52.110000          35.635000
# 50%            70.900000          58.200000          43.210000
# 75%            76.070000          67.880000          55.930000
# max            89.190000          81.460000          76.300000
#
#        Average of Dec-18
# count        5623.000000
# mean           42.477839
# std            11.295638
# min             4.330000
# 25%            33.430000
# 50%            39.560000
# 75%            51.040000
# max            73.540000
#
# [8 rows x 140 columns]

# %%
print("Train Data Description:")
print(train_data.describe())
# Out:
# Train Data Description:
#           patient_id  patient_zip3   patient_age          bmi    population  \
# count   13173.000000  13173.000000  13173.000000  4102.000000  13173.000000
# mean   555441.784939    568.530859     59.271313    29.168808  20651.373928
# std    259476.503094    275.758485     13.218883     5.752820  13840.379638
# min    100043.000000    100.000000     18.000000    15.000000    635.550000
# 25%    335100.000000    330.000000     50.000000    24.825000   9160.340000
# 50%    555769.000000    557.000000     59.000000    28.580000  18952.780000
# 75%    780967.000000    832.000000     67.000000    33.000000  30021.280000
# max    999982.000000    995.000000     91.000000    97.000000  71374.130000
#
#             density    age_median  age_under_10  age_10_to_19       age_20s  \
# count  13173.000000  13173.000000  13173.000000  13173.000000  13173.000000
# mean    1776.872376     40.542676     11.104988     12.857587     13.297375
# std     3876.061897      4.031027      1.511534      1.952248      3.390472
# min        0.920000     20.600000      0.000000      6.310000      5.930000
# 25%      163.150000     37.190000     10.150000     11.650000     11.000000
# 50%      700.340000     40.640000     11.000000     12.900000     12.530000
# 75%     1666.520000     42.940000     12.140000     13.910000     14.970000
# max    29851.690000     54.570000     17.680000     35.300000     62.100000
#
#        ...  Average of Apr-18  Average of May-18  Average of Jun-18  \
# count  ...       13173.000000       13173.000000       13164.000000
# mean   ...          52.411982          67.932236          73.074635
# std    ...          11.069900           6.301740           6.581630
# min    ...          28.790000          45.880000          53.460000
# 25%    ...          42.900000          63.220000          68.050000
# 50%    ...          50.290000          66.120000          71.640000
# 75%    ...          62.220000          72.590000          77.660000
# max    ...          76.490000          86.570000          90.660000
#
#        Average of Jul-18  Average of Aug-18  Average of Sep-18  \
# count       13127.000000       13157.000000       13166.000000
# mean           77.120929          76.281156          71.417027
# std             5.335091           5.282156           6.502875
# min            58.540000          56.200000          51.830000
# 25%            73.170000          72.550000          67.020000
# 50%            76.650000          76.080000          70.880000
# 75%            80.290000          79.130000          75.640000
# max            96.430000          95.770000          89.190000
#
#        Average of Oct-18  Average of Nov-18  Average of Dec-18  \
# count       13166.000000       13161.000000       13140.000000
# mean           59.323286          46.100150          42.096213
# std             9.261934          12.245594          11.209011
# min            37.540000          19.150000          15.380000
# 25%            51.970000          35.560000          33.370000
# 50%            57.450000          42.430000          38.500000
# 75%            67.360000          55.730000          50.500000
# max            81.460000          76.300000          73.540000
#
#        metastatic_diagnosis_period
# count                 13173.000000
# mean                     96.515221
# std                     108.969873
# min                       0.000000
# 25%                       3.000000
# 50%                      44.000000
# 75%                     181.000000
# max                     365.000000
#
# [8 rows x 141 columns]

# %%
print("Test Data Info:")
test_data.info()
# Out:
# Test Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5646 entries, 0 to 5645
# Columns: 151 entries, patient_id to Average of Dec-18
# dtypes: float64(137), int64(3), object(11)
# memory usage: 6.5+ MB

# %%
print("Train Data Info:")
train_data.info()
# Out:
# Train Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13173 entries, 0 to 13172
# Columns: 152 entries, patient_id to metastatic_diagnosis_period
# dtypes: float64(137), int64(4), object(11)
# memory usage: 15.3+ MB

# %% [markdown]
# See the number of rows and columns.
# This information is useful for understanding the size and structure of the dataset,
# which can be crucial for data preprocessing, analysis, and modeling.

# %%
train_data.shape
# Out:
# (13173, 152)

# %%
test_data.shape
# Out:
# (5646, 151)

# %%
race_counts_test = test_data['patient_race'].value_counts()
(race_counts_test)
# Out:
# patient_race
# White       1564
# Black        474
# Hispanic     355
# Other        305
# Asian        163
# Name: count, dtype: int64

# %%
race_counts_train = train_data['patient_race'].value_counts()
(race_counts_train)
# Out:
# patient_race
# White       3565
# Black       1159
# Hispanic     807
# Other        612
# Asian        373
# Name: count, dtype: int64

# %% [markdown]
# We analyze the data in the table and we can see that a large percentage of data is missing from some columns, so we can drop those data.
# We could drop:
# * bmi (~ 68% missing).
# * metastatic_first_novel_treatment (~ 99% data missing).
# * metastatic_first_novel_treatment_type (~ 99% data missing).
#
# Also, some columns do not contain relevant information or contain information that will not help us in the prediction:
# * patient_gender (100% woman)
# * breast_cancer_diagnosis_desc (no relevant info for prediction)
# * patient_id (uniqe for every patient)

# %%
from prettytable import PrettyTable
table = PrettyTable()
target='metastatic_diagnosis_period'
table.field_names = ['Column Name', 'Data Type', 'Train Missing %', 'Test Missing %']
for column in train_data.columns:
    data_type = str(train_data[column].dtype)
    non_null_count_train= 100-train_data[column].count()/train_data.shape[0]*100
    if column!=target:
        non_null_count_test = 100-test_data[column].count()/test_data.shape[0]*100
    else:
        non_null_count_test="NA"
    table.add_row([column, data_type, non_null_count_train,non_null_count_test])
print(table)
# Out:
# +---------------------------------------+-----------+----------------------+----------------------+
# |              Column Name              | Data Type |   Train Missing %    |    Test Missing %    |
# +---------------------------------------+-----------+----------------------+----------------------+
# |               patient_id              |   int64   |         0.0          |         0.0          |
# |              patient_race             |   object  |  50.53518560692325   |  49.32695713779667   |
# |               payer_type              |   object  |  13.398618386092764  |  13.90364860077932   |
# |             patient_state             |   object  |         0.0          |         0.0          |
# |              patient_zip3             |   int64   |         0.0          |         0.0          |
# |                 Region                |   object  |         0.0          |         0.0          |
# |                Division               |   object  |         0.0          |         0.0          |
# |              patient_age              |   int64   |         0.0          |         0.0          |
# |             patient_gender            |   object  |         0.0          |         0.0          |
# |                  bmi                  |  float64  |  68.86054809079178   |   69.8016294721927   |
# |      breast_cancer_diagnosis_code     |   object  |         0.0          |         0.0          |
# |      breast_cancer_diagnosis_desc     |   object  |         0.0          |         0.0          |
# |    metastatic_cancer_diagnosis_code   |   object  |         0.0          |         0.0          |
# |    metastatic_first_novel_treatment   |   object  |  99.91649586274956   |  99.87601842012045   |
# | metastatic_first_novel_treatment_type |   object  |  99.91649586274956   |  99.87601842012045   |
# |               population              |  float64  |         0.0          |         0.0          |
# |                density                |  float64  |         0.0          |         0.0          |
# |               age_median              |  float64  |         0.0          |         0.0          |
# |              age_under_10             |  float64  |         0.0          |         0.0          |
# |              age_10_to_19             |  float64  |         0.0          |         0.0          |
# |                age_20s                |  float64  |         0.0          |         0.0          |
# |                age_30s                |  float64  |         0.0          |         0.0          |
# |                age_40s                |  float64  |         0.0          |         0.0          |
# |                age_50s                |  float64  |         0.0          |         0.0          |
# |                age_60s                |  float64  |         0.0          |         0.0          |
# |                age_70s                |  float64  |         0.0          |         0.0          |
# |              age_over_80              |  float64  |         0.0          |         0.0          |
# |                  male                 |  float64  |         0.0          |         0.0          |
# |                 female                |  float64  |         0.0          |         0.0          |
# |                married                |  float64  |         0.0          |         0.0          |
# |                divorced               |  float64  |         0.0          |         0.0          |
# |             never_married             |  float64  |         0.0          |         0.0          |
# |                widowed                |  float64  |         0.0          |         0.0          |
# |              family_size              |  float64  | 0.037956426022915934 |         0.0          |
# |           family_dual_income          |  float64  | 0.037956426022915934 |         0.0          |
# |        income_household_median        |  float64  | 0.037956426022915934 |         0.0          |
# |        income_household_under_5       |  float64  | 0.037956426022915934 |         0.0          |
# |        income_household_5_to_10       |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_10_to_15       |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_15_to_20       |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_20_to_25       |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_25_to_35       |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_35_to_50       |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_50_to_75       |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_75_to_100      |  float64  | 0.037956426022915934 |         0.0          |
# |      income_household_100_to_150      |  float64  | 0.037956426022915934 |         0.0          |
# |       income_household_150_over       |  float64  | 0.037956426022915934 |         0.0          |
# |      income_household_six_figure      |  float64  | 0.037956426022915934 |         0.0          |
# |        income_individual_median       |  float64  |         0.0          |         0.0          |
# |             home_ownership            |  float64  | 0.037956426022915934 |         0.0          |
# |             housing_units             |  float64  |         0.0          |         0.0          |
# |               home_value              |  float64  | 0.037956426022915934 |         0.0          |
# |              rent_median              |  float64  | 0.037956426022915934 |         0.0          |
# |              rent_burden              |  float64  | 0.037956426022915934 |         0.0          |
# |       education_less_highschool       |  float64  |         0.0          |         0.0          |
# |          education_highschool         |  float64  |         0.0          |         0.0          |
# |         education_some_college        |  float64  |         0.0          |         0.0          |
# |          education_bachelors          |  float64  |         0.0          |         0.0          |
# |           education_graduate          |  float64  |         0.0          |         0.0          |
# |       education_college_or_above      |  float64  |         0.0          |         0.0          |
# |         education_stem_degree         |  float64  |         0.0          |         0.0          |
# |       labor_force_participation       |  float64  |         0.0          |         0.0          |
# |           unemployment_rate           |  float64  |         0.0          |         0.0          |
# |             self_employed             |  float64  | 0.037956426022915934 |         0.0          |
# |                 farmer                |  float64  | 0.037956426022915934 |         0.0          |
# |               race_white              |  float64  |         0.0          |         0.0          |
# |               race_black              |  float64  |         0.0          |         0.0          |
# |               race_asian              |  float64  |         0.0          |         0.0          |
# |              race_native              |  float64  |         0.0          |         0.0          |
# |              race_pacific             |  float64  |         0.0          |         0.0          |
# |               race_other              |  float64  |         0.0          |         0.0          |
# |             race_multiple             |  float64  |         0.0          |         0.0          |
# |                hispanic               |  float64  |         0.0          |         0.0          |
# |                disabled               |  float64  |         0.0          |         0.0          |
# |                poverty                |  float64  | 0.037956426022915934 |         0.0          |
# |            limited_english            |  float64  | 0.037956426022915934 |         0.0          |
# |              commute_time             |  float64  |         0.0          |         0.0          |
# |            health_uninsured           |  float64  |         0.0          |         0.0          |
# |                veteran                |  float64  |         0.0          |         0.0          |
# |           Average of Jan-13           |  float64  |  0.2505124117513162  |  0.1594048884165744  |
# |           Average of Feb-13           |  float64  | 0.02277385561374956  |         0.0          |
# |           Average of Mar-13           |  float64  |         0.0          |         0.0          |
# |           Average of Apr-13           |  float64  |         0.0          |         0.0          |
# |           Average of May-13           |  float64  | 0.02277385561374956  |         0.0          |
# |           Average of Jun-13           |  float64  | 0.15182570409170637  | 0.12398157987956893  |
# |           Average of Jul-13           |  float64  |         0.0          |         0.0          |
# |           Average of Aug-13           |  float64  |  0.1290518484779426  | 0.08855827134254923  |
# |           Average of Sep-13           |  float64  |  0.2049647005238029  | 0.24796315975912364  |
# |           Average of Oct-13           |  float64  |  0.4478858270705217  | 0.47821466524973744  |
# |           Average of Nov-13           |  float64  | 0.02277385561374956  |         0.0          |
# |           Average of Dec-13           |  float64  | 0.02277385561374956  |         0.0          |
# |           Average of Jan-14           |  float64  | 0.03036514081834696  | 0.05313496280552954  |
# |           Average of Feb-14           |  float64  | 0.06832156684126289  | 0.10626992561104487  |
# |           Average of Mar-14           |  float64  | 0.22014727093296926  |  0.3010981225646532  |
# |           Average of Apr-14           |  float64  |  1.366431336825329   |  1.6826071555083217  |
# |           Average of May-14           |  float64  |         0.0          |         0.0          |
# |           Average of Jun-14           |  float64  |  1.1538753510969428  |  1.3992206872121926  |
# |           Average of Jul-14           |  float64  |         0.0          |         0.0          |
# |           Average of Aug-14           |  float64  |         0.0          |         0.0          |
# |           Average of Sep-14           |  float64  |         0.0          |         0.0          |
# |           Average of Oct-14           |  float64  |         0.0          |         0.0          |
# |           Average of Nov-14           |  float64  | 0.18219084491005333  |  0.1594048884165744  |
# |           Average of Dec-14           |  float64  |         0.0          |         0.0          |
# |           Average of Jan-15           |  float64  | 0.04554771122751333  | 0.05313496280552954  |
# |           Average of Feb-15           |  float64  | 0.09109542245502666  | 0.10626992561104487  |
# |           Average of Mar-15           |  float64  | 0.09109542245502666  | 0.10626992561104487  |
# |           Average of Apr-15           |  float64  | 0.21255598572838608  | 0.17711654268508426  |
# |           Average of May-15           |  float64  |         0.0          |         0.0          |
# |           Average of Jun-15           |  float64  |         0.0          |         0.0          |
# |           Average of Jul-15           |  float64  |         0.0          |         0.0          |
# |           Average of Aug-15           |  float64  | 0.16700827450087274  |  0.2656748140276335  |
# |           Average of Sep-15           |  float64  |         0.0          |         0.0          |
# |           Average of Oct-15           |  float64  | 0.12146056327335941  | 0.07084661707403939  |
# |           Average of Nov-15           |  float64  | 0.12146056327335941  | 0.07084661707403939  |
# |           Average of Dec-15           |  float64  |   0.13664313368254   | 0.08855827134254923  |
# |           Average of Jan-16           |  float64  | 0.12146056327335941  | 0.07084661707403939  |
# |           Average of Feb-16           |  float64  | 0.12146056327335941  | 0.07084661707403939  |
# |           Average of Mar-16           |  float64  |         0.0          |         0.0          |
# |           Average of Apr-16           |  float64  |         0.0          |         0.0          |
# |           Average of May-16           |  float64  | 0.14423441888710897  | 0.07084661707403939  |
# |           Average of Jun-16           |  float64  |         0.0          |         0.0          |
# |           Average of Jul-16           |  float64  | 0.12146056327335941  | 0.07084661707403939  |
# |           Average of Aug-16           |  float64  |         0.0          |         0.0          |
# |           Average of Sep-16           |  float64  |         0.0          |         0.0          |
# |           Average of Oct-16           |  float64  |         0.0          |         0.0          |
# |           Average of Nov-16           |  float64  | 0.02277385561374956  |         0.0          |
# |           Average of Dec-16           |  float64  | 0.09868670765960985  | 0.03542330853701969  |
# |           Average of Jan-17           |  float64  | 0.06832156684126289  | 0.05313496280552954  |
# |           Average of Feb-17           |  float64  |         0.0          |         0.0          |
# |           Average of Mar-17           |  float64  |         0.0          |         0.0          |
# |           Average of Apr-17           |  float64  |         0.0          |         0.0          |
# |           Average of May-17           |  float64  |         0.0          |         0.0          |
# |           Average of Jun-17           |  float64  | 0.007591285204583187 | 0.017711654268509847 |
# |           Average of Jul-17           |  float64  | 0.23532984134213564  |  0.2302515054906138  |
# |           Average of Aug-17           |  float64  |         0.0          |         0.0          |
# |           Average of Sep-17           |  float64  | 0.07591285204586029  | 0.03542330853701969  |
# |           Average of Oct-17           |  float64  | 0.15941698929628956  |  0.2656748140276335  |
# |           Average of Nov-17           |  float64  | 0.037956426022915934 | 0.10626992561104487  |
# |           Average of Dec-17           |  float64  |         0.0          |         0.0          |
# |           Average of Jan-18           |  float64  |         0.0          |         0.0          |
# |           Average of Feb-18           |  float64  | 0.037956426022915934 | 0.10626992561104487  |
# |           Average of Mar-18           |  float64  | 0.04554771122751333  | 0.12398157987956893  |
# |           Average of Apr-18           |  float64  |         0.0          |         0.0          |
# |           Average of May-18           |  float64  |         0.0          |         0.0          |
# |           Average of Jun-18           |  float64  | 0.06832156684126289  | 0.08855827134254923  |
# |           Average of Jul-18           |  float64  | 0.34919911941091186  | 0.28338646829614333  |
# |           Average of Aug-18           |  float64  | 0.12146056327335941  | 0.12398157987956893  |
# |           Average of Sep-18           |  float64  | 0.05313899643209652  | 0.03542330853701969  |
# |           Average of Oct-18           |  float64  | 0.05313899643209652  | 0.03542330853701969  |
# |           Average of Nov-18           |  float64  | 0.09109542245502666  | 0.14169323414806456  |
# |           Average of Dec-18           |  float64  |  0.2505124117513162  | 0.40736804817569805  |
# |      metastatic_diagnosis_period      |   int64   |         0.0          |          NA          |
# +---------------------------------------+-----------+----------------------+----------------------+

# %%
import matplotlib.pyplot as plt
gender_counts = train_data['patient_gender'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribuția Genului Pacienților')
plt.axis('equal')  
plt.show()

# %% [markdown]
# We analyze other relevant data to help us with the prediction

# %%
import pandas as pd
import matplotlib.pyplot as plt
bins = [0, 20, 40, 60, 80, 100]
labels = ['0 - 20', '21 - 40', '41 - 60', '61 - 80', '81 - 100']
age_category_counts = pd.cut(train_data['patient_age'], bins=bins, labels=labels, right=False).value_counts()
age_category_counts.plot.bar(figsize=(10, 6), color='skyblue')
plt.title('Number of Patients in Each Age Category')
plt.xlabel('Age Category')
plt.ylabel('Number of Patients')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(train_data['metastatic_diagnosis_period'], bins=20, color='skyblue', edgecolor='black')
counts, bins, _ = plt.hist(train_data['metastatic_diagnosis_period'], bins=20)
for count, x in zip(counts, bins):
    if count != 0:
        plt.text(x + 0.5, count + 0.5, str(int(count)), ha='center', va='bottom')
plt.xlabel('Metastatic Diagnosis Period')
plt.ylabel('Frequency')
plt.title('Histogram of Metastatic Diagnosis Period in Train Data')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(15, 6))
ax.hist(train_data['patient_age'], bins=20, color='skyblue', edgecolor='black', alpha=0.5, label='Train Data')
ax.hist(test_data['patient_age'], bins=20, color='salmon', edgecolor='black', alpha=0.5, label='Test Data')

ax.set_xlabel('Patient Age')
ax.set_ylabel('Frequency')
ax.set_title('Histogram of Patient Age')
ax.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
combined_race_counts = pd.concat([train_data['patient_race'], test_data['patient_race']]).value_counts()
plt.figure(figsize=(15, 6))
bars = plt.bar(combined_race_counts.index, combined_race_counts.values)
plt.xlabel('Patient Race')
plt.ylabel('Count')
plt.title('Distribution of Patient Races')
plt.xticks(rotation=45)
for bar, count in zip(bars, combined_race_counts):
    plt.annotate(str(count), xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()), 
                 xytext=(0, 3), textcoords='offset points',
                 ha='center', va='bottom')

plt.tight_layout() 
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(10, 6))
ax = sns.barplot(data=train_data, x='patient_race', y='metastatic_diagnosis_period',  errorbar=None) 
plt.xlabel('Patient Race')
plt.ylabel('Mean Metastatic Diagnosis Period')
plt.title('Mean Metastatic Diagnosis Period by Patient Race')
plt.xticks(rotation=45)
for bar in ax.patches:
    ax.annotate(format(bar.get_height(), '.2f'), 
                 (bar.get_x() + bar.get_width() / 2, bar.get_height()), 
                 ha='center', va='center',
                 size=10, xytext=(0, 8),
                 textcoords='offset points')

plt.tight_layout()  
plt.show()

# %%
import matplotlib.pyplot as plt
combined_region_counts = pd.concat([train_data['Region'], test_data['Region']]).value_counts()
plt.figure(figsize=(15, 6))
plt.bar(combined_region_counts.index, combined_region_counts.values)
plt.xlabel('Region')
plt.ylabel('Count')
plt.title('Distribution of Patient Region')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 6))
train_race_counts = train_data['patient_race'].value_counts()
test_race_counts = test_data['patient_race'].value_counts()

sns.countplot(data=train_data, x='patient_race', hue='Region', ax=axes[0])
axes[0].set_xlabel('Patient Race')
axes[0].set_ylabel('Count')
axes[0].set_title('Distribution of Patient Races (Train)')
axes[0].tick_params(axis='x', rotation=45) 


sns.countplot(data=test_data, x='patient_race', hue='Region', ax=axes[1])
axes[1].set_xlabel('Patient Race')
axes[1].set_ylabel('Count')
axes[1].set_title('Distribution of Patient Races (Test)')
axes[1].tick_params(axis='x', rotation=45)  

plt.tight_layout() 
plt.show()

# %%
import matplotlib.pyplot as plt
payer_type_counts = train_data['payer_type'].value_counts(normalize=True) * 100
plt.figure(figsize=(8, 6))
plt.pie(payer_type_counts, labels=payer_type_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Payer_Type')
plt.axis('equal')  
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Concatenate the race counts from both train and test datasets
combined_race_counts = pd.concat([train_data['patient_race'], test_data['patient_race']]).value_counts()

# Create the plot
plt.figure(figsize=(15, 6))
bars = plt.bar(combined_race_counts.index, combined_race_counts.values)

# Customize the plot
plt.xlabel('Patient Race')
plt.ylabel('Count')
plt.title('Distribution of Patient Races')
plt.xticks(rotation=45)
for bar, count in zip(bars, combined_race_counts):
    plt.annotate(str(count), xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()), 
                 xytext=(0, 3), textcoords='offset points',
                 ha='center', va='bottom')

plt.tight_layout() 
plt.show()

# %% [markdown]
# Encodes categorical features)

# %%
X = train_data.drop(['patient_id', 'bmi', 'breast_cancer_diagnosis_desc','metastatic_first_novel_treatment', 'patient_gender','metastatic_first_novel_treatment_type','metastatic_diagnosis_period'], axis=1)
y = train_data['metastatic_diagnosis_period']

print(X.shape, y.shape)
X.head()
# Out:
# (13173, 145) (13173,)
#   patient_race  payer_type patient_state  patient_zip3   Region  \
# 0          NaN  COMMERCIAL            AR           724    South
# 1        White         NaN            IL           629  Midwest
# 2          NaN  COMMERCIAL            CA           925     West
# 3     Hispanic    MEDICAID            CA           900     West
# 4          NaN  COMMERCIAL            CA           934     West
#
#              Division  patient_age breast_cancer_diagnosis_code  \
# 0  West South Central           39                       C50912
# 1  East North Central           55                       C50412
# 2             Pacific           59                         1749
# 3             Pacific           59                       C50911
# 4             Pacific           71                         1748
#
#   metastatic_cancer_diagnosis_code  population  ...  Average of Mar-18  \
# 0                             C773     3924.87  ...              50.22
# 1                             C773     2745.39  ...              44.18
# 2                             C773    38343.18  ...              60.97
# 3                             C773    36054.12  ...              59.35
# 4                            C7951    13700.37  ...              55.78
#
#    Average of Apr-18  Average of May-18  Average of Jun-18  Average of Jul-18  \
# 0              52.55              74.77              79.96              81.69
# 1              49.30              72.87              77.40              77.43
# 2              68.50              70.31              78.61              87.24
# 3              63.34              63.10              67.45              75.86
# 4              59.45              60.24              64.77              69.81
#
#    Average of Aug-18  Average of Sep-18  Average of Oct-18  Average of Nov-18  \
# 0              78.30              74.56              59.98              42.98
# 1              75.83              72.64              58.36              39.68
# 2              85.52              80.75              70.81              62.67
# 3              75.24              71.10              68.95              65.46
# 4              70.13              68.10              65.38              60.72
#
#    Average of Dec-18
# 0              41.18
# 1              39.71
# 2              55.58
# 3              59.46
# 4              54.08
#
# [5 rows x 145 columns]

# %% [markdown]
# Splits train_data in training (80%) and testing (20%)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
cols_categorical = X.columns[X.dtypes == 'object'].to_list()

encoder = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1).fit(X[cols_categorical])
X_enc = pd.concat([
    X[X.columns[~X.columns.isin(cols_categorical)]],
    pd.DataFrame(encoder.transform(X[cols_categorical]), columns=cols_categorical)], axis=1)
seed = 40;
X_train, X_test, y_train, y_test = train_test_split(X_enc, y, random_state=seed, stratify=y, test_size=.2)
print('Training size: ', X_train.shape)
print('Testing size: ', X_test.shape)

X_train.head(2)
# Out:
# Training size:  (10538, 145)
# Testing size:  (2635, 145)
#       patient_zip3  patient_age  population  density  age_median  \
# 9189           618           90     5012.28   161.78       43.33
# 3274           164           73     3798.67   129.37       44.24
#
#       age_under_10  age_10_to_19  age_20s  age_30s  age_40s  ...  \
# 9189         10.98         12.57    11.48    11.49    11.38  ...
# 3274         10.36         14.23    10.90    10.34    11.98  ...
#
#       Average of Oct-18  Average of Nov-18  Average of Dec-18  patient_race  \
# 9189              54.91              35.89               34.2           NaN
# 3274              50.55              35.26               32.7           NaN
#
#       payer_type  patient_state  Region  Division  \
# 9189         2.0           13.0     0.0       0.0
# 3274         2.0           33.0     1.0       2.0
#
#       breast_cancer_diagnosis_code  metastatic_cancer_diagnosis_code
# 9189                          39.0                              30.0
# 3274                           1.0                              25.0
#
# [2 rows x 145 columns]
